# %%
import data_handler
import data_plotting
from pathlib import Path
import matplotlib.pyplot as plt
from data_handler import scan_output_dir, DataFile
from data_plotting import rpA_vs_centrality, rpA_vs_y, rpA_vs_pt

# %%
output_dir = "/home/sawin/Desktop/Charmonia/quenching_integration/output_JPsi"

# %%
# 1) R_pA vs centrality (averaged over y & pT)
# Optional mapping centrality -> <N_part>
# cent2npart = {(0,20): 300.0, (20,40): 200.0, (40,60): 120.0, (60,100): 40.0}
fig, ax, data = rpA_vs_centrality(output_dir, particle="JPsi")  # or supply centrality_to_npart=cent2npart
plt.show()
# Out:
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12296 (\N{LEFT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12297 (\N{RIGHT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2) R_pA vs y (averaged over pT; auto-uses minbias if present, else averages over centralities)
fig, ax, data = rpA_vs_y(output_dir, particle="JPsi", pt_range=None)
plt.show()
# Out:
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12296 (\N{LEFT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12297 (\N{RIGHT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 3) R_pA vs pT (averaged over y in a window)
fig, ax, data = rpA_vs_pt(output_dir, particle="JPsi", y_range=(-5.0, -2.5))
plt.show()
# Out:
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12296 (\N{LEFT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/sawin/anaconda3/envs/research/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12297 (\N{RIGHT ANGLE BRACKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from data_handler import DataFile
from single_file_analysis import SingleFileAnalyzer

output_dir = "/home/sawin/Desktop/Charmonia/quenching_integration/output_JPsi"
path = Path(output_dir) / "cent_0-20_JPsi_RpA.tsv"

# load once
an = SingleFileAnalyzer.from_path(path)

print(an.meta)       # {'tag': 'cent_0-20', 'centrality': (0, 20), 'particle': 'JPsi', 'kind': 'RpA'}
print(an.df.head())  # y, pt, value, error
print(an.data_file.to_grid().shape)  # (ny, npt)
print(an.summary())  # mean stats for this file

# 2) Value vs y at pT~2, with error band
fig, ax, s = an.plot_y_curve(pt=2.0, with_errorband=True)
plt.show()

# 3) Value vs pT at y~0, with error band
fig, ax, s = an.plot_pt_curve(y=0.0, with_errorband=True)
plt.show()
# Out:
# {'tag': 'cent_0-20', 'centrality': (0, 20), 'particle': 'JPsi', 'kind': 'RpA'}
#      y   pt     value         error
# 0 -5.0  0.1  0.071880  4.180680e-10
# 1 -5.0  0.6  0.416790  1.059090e-10
# 2 -5.0  1.1  0.699663  9.986430e-11
# 3 -5.0  1.6  0.911455  1.315760e-10
# 4 -5.0  2.1  1.094500  2.003320e-10
# (21, 81)
# {'mean': 6.016519698899339e+26, 'mean_error': 1423309630799.997, 'n_points': 1701, 'meta': {'tag': 'cent_0-20', 'centrality': (0, 20), 'particle': 'JPsi', 'kind': 'RpA'}}

# %%
# 4) Multiple y-curves at a few pT slices
fig, ax = an.plot_multi_y_curves(pts=[0.5, 2.0, 5.0, 10.0])
plt.show()

# 5) Multiple pT-curves at a few y slices
fig, ax = an.plot_multi_pt_curves(ys=[-3.0, 0.0, 3.0])
plt.show()

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from data_handler import DataFile
from single_file_analysis import SingleFileAnalyzer

output_dir = "/home/sawin/Desktop/Charmonia/quenching_integration/output_JPsi"
path = Path(output_dir) / "cent_20-40_JPsi_RpA.tsv"

# load once
an = SingleFileAnalyzer.from_path(path)

print(an.meta)       # {'tag': 'cent_0-20', 'centrality': (0, 20), 'particle': 'JPsi', 'kind': 'RpA'}
print(an.df.head())  # y, pt, value, error
print(an.data_file.to_grid().shape)  # (ny, npt)
print(an.summary())  # mean stats for this file
# Out:
# {'tag': 'cent_20-40', 'centrality': (20, 40), 'particle': 'JPsi', 'kind': 'RpA'}
#      y   pt     value         error
# 0 -5.0  0.1  0.095193  3.259140e-10
# 1 -5.0  0.6  0.489395  9.042780e-11
# 2 -5.0  1.1  0.749318  9.378820e-11
# 3 -5.0  1.6  0.923210  1.299370e-10
# 4 -5.0  2.1  1.064020  2.065860e-10
# (21, 81)
# {'mean': 4.299541449501334e+26, 'mean_error': 8526626298809.822, 'n_points': 1701, 'meta': {'tag': 'cent_20-40', 'centrality': (20, 40), 'particle': 'JPsi', 'kind': 'RpA'}}

# %%
# 2) Value vs y at pT~2, with error band
fig, ax, s = an.plot_y_curve(pt=2.0, with_errorband=True)
plt.show()

# 3) Value vs pT at y~0, with error band
fig, ax, s = an.plot_pt_curve(y=0.0, with_errorband=True)
plt.show()

# %%
# 4) Multiple y-curves at a few pT slices
fig, ax = an.plot_multi_y_curves(pts=[0.5, 2.0, 5.0, 10.0])
plt.show()

# 5) Multiple pT-curves at a few y slices
fig, ax = an.plot_multi_pt_curves(ys=[-3.0, 0.0, 3.0])
plt.show()
